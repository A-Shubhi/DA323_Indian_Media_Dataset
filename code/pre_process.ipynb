# %% [markdown]
# <h1>Scraping data</h1>

# %% [markdown]
# Importing required libraraies

# %%
import pandas as pd
import requests
import re
import os

# %% [markdown]
# Reading the input file

# %%
df = pd.read_csv('News_Articles_Indian_Express.csv')
df.head(2)
# Out:
#    Unnamed: 0   article_id                                           headline  \
# 0           0  INDEXP20000       Trainer aircraft crashes in Odisha, 2 killed
# 1           1  INDEXP19999  Uttarkhand unlock 1.0: Hotel bookings for mini...
#
#                                                 desc  \
# 0  The two were taken to a nearby hospital in Kam...
# 1  All hotels/ B&B/ Homestay & hospitality servic...
#
#                          date  \
# 0   June 8, 2020  11:06:53 am
# 1   June 8, 2020  11:03:16 am
#
#                                                  url  \
# 0  https://indianexpress.com/article/india/traine...
# 1  https://indianexpress.com/article/india/touris...
#
#                                             articles article_type  \
# 0  A two-seater aircraft crashed in Odisha's Dhen...        short
# 1  Hotels located in non-containment zones can re...         long
#
#    article_length
# 0             753
# 1            2424

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'article_id', 'headline', 'desc', 'date', 'url',
#        'articles', 'article_type', 'article_length'],
#       dtype='object')

# %% [markdown]
# Extracting Image URLs from the webpage URL

# %%
def extract_image_url_from_url(article_url):
    '''This function returns the Image URL'''
    try:
        # Fetch the HTML content of the article URL
        response = requests.get(article_url, timeout = 10)
        response.raise_for_status()  # Raise an exception for bad status codes
        html_content = response.text
        
        # Find all <img> tags in the HTML content with class containing 'wp-image-'
        img_tags = re.findall(r'<img.*?class=".*?wp-image-\d+.*?".*?src="(.*?)"', html_content)
        
        # Return the first image URL if found, otherwise return None
        return img_tags[0] if img_tags else None
    except Exception as e:
        print(f"Error occurred while extracting image URL from {article_url}: {e}")
        return None

# %%
def process_and_save_in_batches(df, batch_size):
    '''This function adds a new column to the existing csv in which we store the URL of the image. The task is performed in batches.'''
    if 'image_url' not in df.columns:
        df['image_url'] = None  
    num_batches = len(df) // batch_size + 1
    for batch_num in range(num_batches):
        updated_csv_filename = f'data\\updated_csv_batch_{batch_num}.csv'
        start_index = batch_num * batch_size
        end_index = min((batch_num + 1) * batch_size, len(df))
        
        # Check if the updated CSV file already exists
        if os.path.exists(updated_csv_filename):
            # Read the existing CSV file and update the 'image_url' column
            existing_df = pd.read_csv(updated_csv_filename)
            existing_df['image_url'] = existing_df.apply(lambda row: extract_image_url_from_url(row['url']) if pd.isna(row['image_url']) else row['image_url'], axis=1)
            existing_df.to_csv(updated_csv_filename, index=False)
            print(f"Batch {batch_num + 1} added to existing CSV file: {updated_csv_filename}")
        else:
            batch_df = df[start_index:end_index].copy()  # Create a copy of the batch DataFrame
            batch_df['image_url'] = batch_df.apply(lambda row: extract_image_url_from_url(row['url']) if pd.isna(row['image_url']) else row['image_url'], axis=1)
            # Save the updated DataFrame as a new CSV file
            batch_df.to_csv(updated_csv_filename, index=False)
            print(f"Batch {batch_num + 1} processed and saved to {updated_csv_filename}")

# %%
# Process and save DataFrame in batches of size 100
batch_size = 100
process_and_save_in_batches(df, batch_size)
# Out:
# Batch 1 added to existing CSV file: data\updated_csv_batch_0.csv
# Batch 2 added to existing CSV file: data\updated_csv_batch_1.csv
# Batch 3 added to existing CSV file: data\updated_csv_batch_2.csv
# Batch 4 added to existing CSV file: data\updated_csv_batch_3.csv
# Batch 5 added to existing CSV file: data\updated_csv_batch_4.csv
# Batch 6 added to existing CSV file: data\updated_csv_batch_5.csv
# Batch 7 added to existing CSV file: data\updated_csv_batch_6.csv
# Batch 8 added to existing CSV file: data\updated_csv_batch_7.csv
# Batch 9 added to existing CSV file: data\updated_csv_batch_8.csv
# Batch 10 added to existing CSV file: data\updated_csv_batch_9.csv
# Batch 11 added to existing CSV file: data\updated_csv_batch_10.csv
# Batch 12 added to existing CSV file: data\updated_csv_batch_11.csv
# Batch 13 added to existing CSV file: data\updated_csv_batch_12.csv
# Batch 14 added to existing CSV file: data\updated_csv_batch_13.csv
# Batch 15 added to existing CSV file: data\updated_csv_batch_14.csv
# Batch 16 added to existing CSV file: data\updated_csv_batch_15.csv
# Batch 17 added to existing CSV file: data\updated_csv_batch_16.csv
# Batch 18 added to existing CSV file: data\updated_csv_batch_17.csv
# Batch 19 added to existing CSV file: data\updated_csv_batch_18.csv
# Batch 20 added to existing CSV file: data\updated_csv_batch_19.csv
# Batch 21 added to existing CSV file: data\updated_csv_batch_20.csv
# Batch 22 added to existing CSV file: data\updated_csv_batch_21.csv
# Batch 23 added to existing CSV file: data\updated_csv_batch_22.csv
# Batch 24 added to existing CSV file: data\updated_csv_batch_23.csv
# Batch 25 added to existing CSV file: data\updated_csv_batch_24.csv
# Batch 26 added to existing CSV file: data\updated_csv_batch_25.csv
# Batch 27 added to existing CSV file: data\updated_csv_batch_26.csv
# Batch 28 added to existing CSV file: data\updated_csv_batch_27.csv
# Batch 29 added to existing CSV file: data\updated_csv_batch_28.csv
# Batch 30 added to existing CSV file: data\updated_csv_batch_29.csv
# Batch 31 added to existing CSV file: data\updated_csv_batch_30.csv
# Batch 32 added to existing CSV file: data\updated_csv_batch_31.csv
# Batch 33 added to existing CSV file: data\updated_csv_batch_32.csv
# Batch 34 added to existing CSV file: data\updated_csv_batch_33.csv
# Batch 35 added to existing CSV file: data\updated_csv_batch_34.csv
# Batch 36 added to existing CSV file: data\updated_csv_batch_35.csv
# Batch 37 added to existing CSV file: data\updated_csv_batch_36.csv
# Batch 38 added to existing CSV file: data\updated_csv_batch_37.csv
# Batch 39 added to existing CSV file: data\updated_csv_batch_38.csv
# Batch 40 added to existing CSV file: data\updated_csv_batch_39.csv
# Batch 41 added to existing CSV file: data\updated_csv_batch_40.csv
# Batch 42 added to existing CSV file: data\updated_csv_batch_41.csv
# Batch 43 added to existing CSV file: data\updated_csv_batch_42.csv
# Batch 44 added to existing CSV file: data\updated_csv_batch_43.csv
# Batch 45 added to existing CSV file: data\updated_csv_batch_44.csv
# Batch 46 added to existing CSV file: data\updated_csv_batch_45.csv
# Batch 47 added to existing CSV file: data\updated_csv_batch_46.csv
# Batch 48 added to existing CSV file: data\updated_csv_batch_47.csv
# Batch 49 added to existing CSV file: data\updated_csv_batch_48.csv
# Batch 50 added to existing CSV file: data\updated_csv_batch_49.csv
# Batch 51 added to existing CSV file: data\updated_csv_batch_50.csv
# Batch 52 added to existing CSV file: data\updated_csv_batch_51.csv
# Batch 53 added to existing CSV file: data\updated_csv_batch_52.csv
# Batch 54 added to existing CSV file: data\updated_csv_batch_53.csv
# Batch 55 added to existing CSV file: data\updated_csv_batch_54.csv
# Batch 56 added to existing CSV file: data\updated_csv_batch_55.csv
# Batch 57 added to existing CSV file: data\updated_csv_batch_56.csv
# Batch 58 added to existing CSV file: data\updated_csv_batch_57.csv
# Batch 59 added to existing CSV file: data\updated_csv_batch_58.csv
# Batch 60 added to existing CSV file: data\updated_csv_batch_59.csv
# Batch 61 added to existing CSV file: data\updated_csv_batch_60.csv
# Batch 62 added to existing CSV file: data\updated_csv_batch_61.csv
# Batch 63 added to existing CSV file: data\updated_csv_batch_62.csv
# Batch 64 added to existing CSV file: data\updated_csv_batch_63.csv
# Batch 65 added to existing CSV file: data\updated_csv_batch_64.csv
# Batch 66 added to existing CSV file: data\updated_csv_batch_65.csv
# Batch 67 added to existing CSV file: data\updated_csv_batch_66.csv
# Batch 68 added to existing CSV file: data\updated_csv_batch_67.csv
# Batch 69 added to existing CSV file: data\updated_csv_batch_68.csv
# Batch 70 added to existing CSV file: data\updated_csv_batch_69.csv
# Batch 71 added to existing CSV file: data\updated_csv_batch_70.csv
# Batch 72 added to existing CSV file: data\updated_csv_batch_71.csv
# Batch 73 added to existing CSV file: data\updated_csv_batch_72.csv
# Batch 74 added to existing CSV file: data\updated_csv_batch_73.csv
# Batch 75 added to existing CSV file: data\updated_csv_batch_74.csv
# Batch 76 added to existing CSV file: data\updated_csv_batch_75.csv
# Batch 77 added to existing CSV file: data\updated_csv_batch_76.csv
# Batch 78 added to existing CSV file: data\updated_csv_batch_77.csv
# Batch 79 added to existing CSV file: data\updated_csv_batch_78.csv
# Batch 80 added to existing CSV file: data\updated_csv_batch_79.csv
# Batch 81 added to existing CSV file: data\updated_csv_batch_80.csv
# Batch 82 added to existing CSV file: data\updated_csv_batch_81.csv
# Batch 83 added to existing CSV file: data\updated_csv_batch_82.csv
# Batch 84 added to existing CSV file: data\updated_csv_batch_83.csv
# Batch 85 added to existing CSV file: data\updated_csv_batch_84.csv
# Batch 86 added to existing CSV file: data\updated_csv_batch_85.csv
# Batch 87 added to existing CSV file: data\updated_csv_batch_86.csv
# Batch 88 added to existing CSV file: data\updated_csv_batch_87.csv
# Batch 89 added to existing CSV file: data\updated_csv_batch_88.csv
# Batch 90 added to existing CSV file: data\updated_csv_batch_89.csv
# Batch 91 added to existing CSV file: data\updated_csv_batch_90.csv
# Batch 92 added to existing CSV file: data\updated_csv_batch_91.csv
# Batch 93 added to existing CSV file: data\updated_csv_batch_92.csv
# Batch 94 added to existing CSV file: data\updated_csv_batch_93.csv
# Batch 95 added to existing CSV file: data\updated_csv_batch_94.csv
# Batch 96 added to existing CSV file: data\updated_csv_batch_95.csv
# Batch 97 added to existing CSV file: data\updated_csv_batch_96.csv
# Batch 98 added to existing CSV file: data\updated_csv_batch_97.csv
# Batch 99 added to existing CSV file: data\updated_csv_batch_98.csv
# Batch 100 added to existing CSV file: data\updated_csv_batch_99.csv
# Error occurred while extracting image URL from https://indianexpress.com/article/india/india-others/2020-bank-holidays-in-india-here-is-the-full-list-6186106/: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# Batch 101 added to existing CSV file: data\updated_csv_batch_100.csv
# Batch 102 added to existing CSV file: data\updated_csv_batch_101.csv
# Batch 103 added to existing CSV file: data\updated_csv_batch_102.csv
# Error occurred while extracting image URL from https://indianexpress.com/article/india/jharkhand-bangladeshi-arrested-with-fake-aadhaar-indian-voter-cards-6178656/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/jharkhand-bangladeshi-arrested-with-fake-aadhaar-indian-voter-cards-6178656/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Batch 104 added to existing CSV file: data\updated_csv_batch_103.csv
# Batch 105 added to existing CSV file: data\updated_csv_batch_104.csv
# Batch 106 added to existing CSV file: data\updated_csv_batch_105.csv
# Batch 107 added to existing CSV file: data\updated_csv_batch_106.csv
# Batch 108 added to existing CSV file: data\updated_csv_batch_107.csv
# Batch 109 added to existing CSV file: data\updated_csv_batch_108.csv
# Error occurred while extracting image URL from https://indianexpress.com/article/india/indian-express-files-contempt-plea-against-bengaluru-publisher-6164185/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/indian-express-files-contempt-plea-against-bengaluru-publisher-6164185/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Batch 110 added to existing CSV file: data\updated_csv_batch_109.csv
# Error occurred while extracting image URL from https://indianexpress.com/article/india/gujarat-hindu-outfit-calls-for-religious-identification-say-tribals-activists-6161117/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/gujarat-hindu-outfit-calls-for-religious-identification-say-tribals-activists-6161117/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Batch 111 added to existing CSV file: data\updated_csv_batch_110.csv
# Batch 112 added to existing CSV file: data\updated_csv_batch_111.csv
# Batch 113 added to existing CSV file: data\updated_csv_batch_112.csv
# Batch 114 added to existing CSV file: data\updated_csv_batch_113.csv
# Batch 115 added to existing CSV file: data\updated_csv_batch_114.csv
# Batch 116 added to existing CSV file: data\updated_csv_batch_115.csv
# Error occurred while extracting image URL from https://indianexpress.com/article/india/bjp-skilled-at-selling-not-creating-priyanka-gandhi-after-cag-report-on-railways-6148294/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/bjp-skilled-at-selling-not-creating-priyanka-gandhi-after-cag-report-on-railways-6148294/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/kerala/kerala-sthree-sakthi-lottery-ss-186-today-results-winner-to-take-home-rs-70-lakh-6148041/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/kerala/kerala-sthree-sakthi-lottery-ss-186-today-results-winner-to-take-home-rs-70-lakh-6148041/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/parliament-live-updates-bjp-congress-lok-sabha-rajya-sabha-bills-6148227/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/parliament-live-updates-bjp-congress-lok-sabha-rajya-sabha-bills-6148227/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/govt-open-to-further-reforms-plans-to-invest-about-rs-1-lakh-crore-in-infrastructure-sector-sitharaman-6148111/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/govt-open-to-further-reforms-plans-to-invest-about-rs-1-lakh-crore-in-infrastructure-sector-sitharaman-6148111/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/god-save-indias-economy-chidambaram-on-nishikant-dubeys-gdp-remark-6148126/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/god-save-indias-economy-chidambaram-on-nishikant-dubeys-gdp-remark-6148126/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/haryana-anil-vij-launches-drive-for-90-full-immunisation-in-two-districts-6148119/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/haryana-anil-vij-launches-drive-for-90-full-immunisation-in-two-districts-6148119/ (Caused by SSLError(CertificateError("hostname 'indianexpress.com' doesn't match either of '*.iitg.ac.in', 'iitg.ac.in'")))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/ghaziabad-couple-woman-jump-off-8th-floor-after-allegedly-killing-two-kids-6148108/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india
: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/signs-of-eid-in-kargil-bakarwals-arrive-with-sheep-5895400/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F20B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/two-days-after-kerala-rain-buried-houses-under-hill-46-missing-5895299/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/two-days-after-kerala-rain-buried-houses-under-hill-46-missing-5895299/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F2470>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/mp-plans-vedic-city-temple-management-institute-5895382/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/mp-plans-vedic-city-temple-management-institute-5895382/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F2230>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/how-up-police-is-using-whatsapp-to-bust-fake-news-5895288/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/how-up-police-is-using-whatsapp-to-bust-fake-news-5895288/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F23E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/bms-plans-protest-against-centres-policies-on-workers-5895385/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/bms-plans-protest-against-centres-policies-on-workers-5895385/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F35B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/gujarat-hc-commutes-life-sentence-of-man-to-10-years-in-jail-5895374/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/gujarat-hc-commutes-life-sentence-of-man-to-10-years-in-jail-5895374/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F29B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/experts-to-brief-mps-on-technical-aspects-of-legislation-om-birla-5895377/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/experts-to-brief-mps-on-technical-aspects-of-legislation-om-birla-5895377/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F2EC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/dna-sampling-in-rape-cases-mp-showcauses-1256-police-officials-5895376/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/dna-sampling-in-rape-cases-mp-showcauses-1256-police-officials-5895376/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F3250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/sonia-gandhi-to-rahul-gandhi-to-sonia-congress-takes-step-back-to-move-forward-5895367/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/sonia-gandhi-to-rahul-gandhi-to-sonia-congress-takes-step-back-to-move-forward-5895367/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F36D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/pay-cash-relief-flood-hit-people-congress-sachin-sawant-fadnavis-5895355/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/pay-cash-relief-flood-hit-people-congress-sachin-sawant-fadnavis-5895355/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F35E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/maharashtra-floods-govt-asks-oil-industry-to-airlift-fuel-to-kolhapur-5895354/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/maharashtra-floods-govt-asks-oil-industry-to-airlift-fuel-to-kolhapur-5895354/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F33D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error occurred while extracting image URL from https://indianexpress.com/article/india/jammu-and-kashmir-bjp-wants-some-curbs-to-be-put-on-outsiders-over-land-govt-jobs-5895341/: HTTPSConnectionPool(host='indianexpress.com', port=443): Max retries exceeded with url: /article/india/jammu-and-kashmir-bjp-wants-some-curbs-to-be-put-on-outsiders-over-land-govt-jobs-5895341/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DE289F1CF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Batch 200 added to existing CSV file: data\updated_csv_batch_199.csv
# Error occurred while extracting image URL from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Batch 201 added to existing CSV file: data\updated_csv_batch_200.csv

# %% [markdown]
# Saving Images to a new folder

# %%
def save_images_from_csvs(csv_folder):
    # Create the 'images' folder if it doesn't exist
    os.makedirs('images', exist_ok=True)
    
    # Iterate through each CSV file in the specified folder
    for filename in os.listdir(csv_folder):
        if filename.startswith('updated_csv_batch_') and filename.endswith('.csv'):
            filepath = os.path.join(csv_folder, filename)
            print(filepath)
            df = pd.read_csv(filepath)
            for index, row in df.iterrows():
                image_url = row['image_url']
                article_id = row['article_id']
                if pd.notnull(image_url):
                    image_filename = os.path.join('images', f"{article_id}.jpg")
                    # Check if image with the same name already exists in the 'images' folder
                    if not os.path.exists(image_filename):
                        try:
                            image_data = requests.get(image_url).content
                            with open(image_filename, 'wb') as f:
                                f.write(image_data)
                            print(f"Image saved: {image_filename}")
                        except Exception as e:
                            print(f"Error occurred while downloading image for article {article_id}: {e}")
                    # else:
                    #     print(f"Image for article {article_id} already exists, skipping download")

# %%
# Image saved: images\INDEXP15949.jpg
# Image saved: images\INDEXP15947.jpg
# data2\updated_csv_batch_41.csv
# data2\updated_csv_batch_42.csv
# data2\updated_csv_batch_43.csv
# data2\updated_csv_batch_44.csv
# data2\updated_csv_batch_45.csv
# data2\updated_csv_batch_46.csv
# data2\updated_csv_batch_47.csv
# data2\updated_csv_batch_48.csv
# data2\updated_csv_batch_49.csv
# data2\updated_csv_batch_5.csv
# data2\updated_csv_batch_50.csv
# data2\updated_csv_batch_51.csv
# data2\updated_csv_batch_52.csv
# data2\updated_csv_batch_53.csv
# data2\updated_csv_batch_54.csv
# data2\updated_csv_batch_55.csv
# data2\updated_csv_batch_56.csv
# data2\updated_csv_batch_57.csv
# data2\updated_csv_batch_58.csv
# data2\updated_csv_batch_59.csv
# data2\updated_csv_batch_6.csv
# data2\updated_csv_batch_60.csv
# data2\updated_csv_batch_61.csv
# data2\updated_csv_batch_62.csv
# data2\updated_csv_batch_63.csv
# data2\updated_csv_batch_64.csv
# data2\updated_csv_batch_65.csv
# data2\updated_csv_batch_66.csv
# data2\updated_csv_batch_67.csv
# data2\updated_csv_batch_68.csv
# data2\updated_csv_batch_69.csv
# data2\updated_csv_batch_7.csv
# data2\updated_csv_batch_70.csv
# data2\updated_csv_batch_71.csv
# data2\updated_csv_batch_72.csv
# data2\updated_csv_batch_73.csv
# data2\updated_csv_batch_74.csv
# Image saved: images\INDEXP12591.jpg
# data2\updated_csv_batch_75.csv
# data2\updated_csv_batch_76.csv
# data2\updated_csv_batch_77.csv
# data2\updated_csv_batch_78.csv
# data2\updated_csv_batch_79.csv
# data2\updated_csv_batch_8.csv
# data2\updated_csv_batch_80.csv
# data2\updated_csv_batch_81.csv
# data2\updated_csv_batch_82.csv
# data2\updated_csv_batch_83.csv
# data2\updated_csv_batch_84.csv
# data2\updated_csv_batch_85.csv
# data2\updated_csv_batch_86.csv
# data2\updated_csv_batch_87.csv
# data2\updated_csv_batch_88.csv
# data2\updated_csv_batch_89.csv
# data2\updated_csv_batch_9.csv
# data2\updated_csv_batch_90.csv
# data2\updated_csv_batch_91.csv
# data2\updated_csv_batch_92.csv
# data2\updated_csv_batch_93.csv
# data2\updated_csv_batch_94.csv
# data2\updated_csv_batch_95.csv
# data2\updated_csv_batch_96.csv
# data2\updated_csv_batch_97.csv
# data2\updated_csv_batch_98.csv
# data2\updated_csv_batch_99.csv

# %% [markdown]
# Counting the number of images left

# %%
def count_null_image_urls(csv_folder, count = 0):
    '''This function checks in how many csvs the image url is not added.'''
    
    for filename in os.listdir(csv_folder):
        if filename.startswith('updated_csv_batch_') and filename.endswith('.csv'):
            filepath = os.path.join(csv_folder, filename)
            df = pd.read_csv(filepath)
            null_count = df['image_url'].isnull().sum()
            # if null_count > 0 :
            #     print(f"Number of null values in {filename}: {null_count}")
            # else:
            count+=null_count
    print(f"Non zeros are {count}" )

# %%
# Call the function with the folder containing the CSV files
csv_folder = 'data'  # Update this with the path to your CSV folder
count_null_image_urls(csv_folder)
# Out:
# Non zeros are 6531

# %%
#  Call the function with the folder containing the CSV files
csv_folder = 'data2'  # Update this with the path to your CSV folder
count_null_image_urls(csv_folder)
# Out:
# Non zeros are 5838

# %% [markdown]
# Combing all the csv into a single one

# %%
folder_path = 'data'

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

dfs = []

# Iterate through each CSV file and read it into a DataFrame
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dfs.append(df)

# Concatenate all DataFrames into one
combined_df = pd.concat(dfs, ignore_index=True)

# Path to save the combined CSV file
combined_csv_path = 'modified.csv'

# Write the combined DataFrame to a CSV file
combined_df.to_csv(combined_csv_path, index=False)

print("Combined CSV file created successfully!")

# %%
def remove_columns_from_csv(file_path):
    '''This function removes columns from the csvs.'''
    df = pd.read_csv(file_path)
    
    # Drop specified columns
    columns_to_remove = ['date', 'articles', 'article_type', 'article_length']
    df = df.drop(columns_to_remove, axis=1)
    
    # Save the modified DataFrame back to CSV
    df.to_csv(file_path, index=False)

# Path to the folder containing CSV files
folder_path = 'data'

# Iterate over each file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(folder_path, file_name)
        remove_columns_from_csv(file_path)

# %% [markdown]
# Creating a new dataframe which consists of images left after hand-filtering. Iterating through all the csv and checking if any image with file name as the article id exist or not . If exist, append its value in he dataframe otherwise not.

# %%
# Path to the folder containing CSV files
data_folder = 'data'

# Path to the folder containing images
image_folder = 'original_image'

# Initialize a list to store the extracted data
data_list = []

# Path to the new CSV file
new_csv_filename = 'extracted_data.csv'

# Check if the new CSV file already exists
if os.path.exists(new_csv_filename):
    # Read the existing CSV file into a DataFrame
    existing_df = pd.read_csv(new_csv_filename)
else:
    # If the new CSV file does not exist, create an empty DataFrame
    existing_df = pd.DataFrame(columns=['article_id', 'url', 'image_url', 'headline', 'desc'])

# Iterate through the CSV files in the 'data' folder
for csv_filename in os.listdir('data'):
    if csv_filename.endswith('.csv'):
        # Read the CSV file
        csv_filepath = os.path.join(data_folder, csv_filename)
        df = pd.read_csv(csv_filepath)

        # Iterate through each row in the DataFrame
        for index, row in df.iterrows():
            article_id = row['article_id']

            # Check if the image file exists
            image_filename = f"{article_id}.jpg"
            image_filepath = os.path.join(image_folder, image_filename)
            if os.path.exists(image_filepath):
                # Check if the article_id already exists in the existing DataFrame
                if article_id in existing_df['article_id'].values:
                    continue  # Skip if article_id already exists in the DataFrame

                # Extract the values of 'url', 'image_url', 'headline', and 'desc'
                url = row['url']
                image_url = row['image_url']
                headline = row['headline']
                desc = row['desc']

                # Append the extracted data to the list
                data_list.append({'article_id': article_id, 'url': url, 'image_url': image_url, 'headline': headline, 'desc': desc})

# Create a new DataFrame from the extracted data list
new_df = pd.DataFrame(data_list)

# Concatenate the existing DataFrame and the new DataFrame
existing_df = pd.concat([existing_df, new_df], ignore_index=True)

# Save the concatenated DataFrame back to the CSV file
existing_df.to_csv(new_csv_filename, index=False)

print(f"Data extracted and saved to {new_csv_filename}")
# Out:
# Data extracted and saved to extracted_data.csv

# %% [markdown]
# Resized the images to a fixed size

# %%
from PIL import Image

def resize_images(input_dir, output_dir, target_size=(256, 256)):
    '''This function resizes all the images to a target size.'''
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for filename in os.listdir(input_dir):
        if filename.endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif')):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            img = Image.open(input_path)
            img = img.resize(target_size, Image.ANTIALIAS)
            img.save(output_path)

# Example usage:
input_dir = 'trial'
output_dir = 'resized_trial'
resize_images(input_dir, output_dir)
# Out:
# C:\Users\Shubhi Agarwal\AppData\Local\Temp\ipykernel_14196\2825778762.py:13: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize(target_size, Image.ANTIALIAS)

# %%
df_new = pd.read_csv('extracted_data.csv')
df_new.shape
# Out:
# (75, 5)

# %%
df_new.columns
# Out:
# Index(['article_id', 'url', 'image_url', 'headline', 'desc'], dtype='object')

# %% [markdown]
# <h1>Headline Manipulation : Fake Headline by inverting semantics</h1>

# %%
positive_to_negative = {

    'open':'close',
    'close':'open',
    'arrest':'release',
    'against': 'for',
    'good': 'bad',
    'great': 'disastrous',
    'positive': 'negative',
    'success': 'failure',
    'victory': 'defeat',
    'progress': 'regression',
    'win': 'loss',
    'heroic': 'villainous',
    'honor': 'dishonor',
    'uplifting': 'demoralizing',
    'hopeful': 'dismal',
    'inspiring': 'discouraging',
    'prosperous': 'ailing',
    'triumph': 'suffering',
    'benevolent': 'malevolent',
    'ethical': 'unethical',
    'righteous': 'corrupt',
    'virtuous': 'immoral',
    'beneficial': 'harmful',
    'savior': 'tyrant',
    'leader': 'dictator',
    'freedom': 'oppression',
    'liberty': 'tyranny',
    'justice': 'injustice',
    'fairness': 'unfairness',
    'equality': 'inequality',
    'peaceful': 'turbulent',
    'stable': 'unstable',
    'strong': 'weak',
    'powerful': 'powerless',
    'confident': 'doubtful',
    'optimistic': 'pessimistic',
    'bright': 'bleak',
    'radiant': 'gloomy',
    'hope': 'despair',
    'support': 'opposition',
    'unity': 'division',
    'collaboration': 'conflict',
    'harmony': 'discord',
    'cooperation': 'dissension',
    'agreement': 'disagreement',
    'consensus': 'disunity',
    'solidarity': 'disunity',
    'trust': 'distrust',
    'credibility': 'doubt',
    'reliable': 'unreliable',
    'credible': 'incredible',
    'transparent': 'opaque',
    'openness': 'secrecy',
    'accountability': 'unaccountability',
    'responsibility': 'irresponsibility',
    'honesty': 'dishonesty',
    'integrity': 'corruption',
    'ethical': 'unethical',
    'upright': 'crooked',
    'humble': 'arrogant',
    'modest': 'immodest',
    'selfless': 'selfish',
    'sacrifice': 'selfishness',
    'compassion': 'indifference',
    'empathy': 'apathy',
    'charitable': 'stingy',
    'philanthropic': 'greedy',
    'generous': 'selfish',
    'altruistic': 'self-serving',
    'noble': 'ignoble',
    'honorable': 'dishonorable',
    'prestigious': 'disreputable',
    'dignified': 'undignified',
    'respectable': 'disreputable',
    'esteemed': 'disreputable',
    'admired': 'disliked',
    'beloved': 'hated',
    'cherished': 'despised',
    'hero': 'villain',
    'icon': 'pariah',
    'idol': 'scoundrel',
    'legend': 'infamous',
    'role model': 'example of what not to do',
    'inspiration': 'source of dismay',
    'idolized': 'vilified',
    'worshiped': 'reviled',
    'glorified': 'condemned',
    'exemplary': 'reprehensible',
    'paragon': 'pariah',
    'pioneer': 'renegade',
    'visionary': 'heretic',
    'trailblazer': 'outcast',
    'maverick': 'rebel',
    'innovative': 'subversive',
    'revolutionary': 'counter-revolutionary',
    'groundbreaking': 'radical',
    'bold': 'reckless',
    'courageous': 'cowardly',
    'brave': 'fearful',
    'fearless': 'timid',
    'daring': 'cautious',
    'audacious': 'timid',
    'gallant': 'pusillanimous',
    'valiant': 'pusillanimous',
    'heroic': 'cowardly',
    'intrepid': 'fearful',
    'bold': 'faint-hearted',
    'venturesome': 'timid',
    'adventurous': 'unadventurous',
    'risk-taking': 'risk-averse',
    'admirable': 'pitiful',
    'laudable': 'pitiable',
    'praiseworthy': 'contemptible',
    'commendable': 'despicable',
    'noteworthy': 'deplorable',
    'applauded': 'berated',
    'applause': 'criticism',
    'disappointed':'proud',
    'acclaimed': 'condemned',
    'celebrated': 'maligned',
    'acknowledged': 'disregarded',
    'recognized': 'ignored',
    'eminent': 'obscure',
    'renowned': 'unknown',
    'famous': 'obscure',
    'illustrious': 'disreputable',
    'respected': 'disrespected',
    'honored': 'dishonored',
    'esteemed': 'disesteemed',
    'adored': 'reviled',
    'revered': 'vilified',
    'venerated': 'condemned',
    'glorified': 'abhorred',
    'lowly': 'highly',
    'poorly regarded': 'well-regarded',
    'loss':'gain', 
    'gain':'loss',
    'poorly': 'highly',
    'protest': 'celebrate',
    'dis':'',
    'for':'against',
    'praise':'criticise',
    'happy':'sad',
    'sad':'happy',
    'proud':'disappointed',
    'small':'big',
    'big':'small',
}

# %%
negative_to_positive = {


    'close':'open',
    'open':'close',
    'arrest':'release',
    'release':'arrest',
    'against': 'for',
    'bad': 'good',
    'disastrous': 'great',
    'negative': 'positive',
    'failure': 'success',
    'defeat': 'victory',
    'regression': 'progress',
    'loss': 'win',
    'villainous': 'heroic',
    'dishonor': 'honor',
    'demoralizing': 'uplifting',
    'dismal': 'hopeful',
    'discouraging': 'inspiring',
    'ailing': 'prosperous',
    'suffering': 'triumph',
    'malevolent': 'benevolent',
    'unethical': 'ethical',
    'corrupt': 'righteous',
    'immoral': 'virtuous',
    'harmful': 'beneficial',
    'tyrant': 'savior',
    'dictator': 'leader',
    'oppression': 'freedom',
    'tyranny': 'liberty',
    'injustice': 'justice',
    'unfairness': 'fairness',
    'inequality': 'equality',
    'turbulent': 'peaceful',
    'unstable': 'stable',
    'weak': 'strong',
    'powerless': 'powerful',
    'doubtful': 'confident',
    'pessimistic': 'optimistic',
    'bleak': 'bright',
    'gloomy': 'radiant',
    'despair': 'hope',
    'opposition': 'support',
    'division': 'unity',
    'conflict': 'collaboration',
    'discord': 'harmony',
    'dissension': 'cooperation',
    'disagreement': 'agreement',
    'disunity': 'consensus',
    'distrust': 'trust',
    'doubt': 'credibility',
    'unreliable': 'reliable',
    'incredible': 'credible',
    'opaque': 'transparent',
    'secrecy': 'openness',
    'unaccountability': 'accountability',
    'irresponsibility': 'responsibility',
    'dishonesty': 'honesty',
    'corruption': 'integrity',
    'unethical': 'ethical',
    'crooked': 'upright',
    'arrogant': 'humble',
    'immodest': 'modest',
    'selfishness': 'sacrifice',
    'selfish': 'selfless',
    'indifference': 'compassion',
    'apathy': 'empathy',
    'stingy': 'charitable',
    'greedy': 'philanthropic',
    'selfish': 'generous',
    'self-serving': 'altruistic',
    'ignoble': 'noble',
    'dishonorable': 'honorable',
    'disreputable': 'prestigious',
    'undignified': 'dignified',
    'dislike': 'admired',
    'hate': 'belove',
    'despised': 'cherished',
    'villain': 'hero',
    'pariah': 'icon',
    'scoundrel': 'idol',
    'infamous': 'legend',
    'example of what not to do': 'role model',
    'source of dismay': 'inspiration',
    'vilified': 'idolized',
    'reviled': 'worshiped',
    'condemned': 'glorified',
    'reprehensible': 'exemplary',
    'pariah': 'paragon',
    'renegade': 'pioneer',
    'heretic': 'visionary',
    'outcast': 'trailblazer',
    'rebel': 'maverick',
    'subversive': 'innovative',
    'counter-revolutionary': 'revolutionary',
    'radical': 'groundbreaking',
    'reckless': 'bold',
    'cowardly': 'courageous',
    'fearful': 'brave',
    'timid': 'fearless',
    'cautious': 'daring',
    'timid': 'audacious',
    'pusillanimous': 'gallant',
    'pusillanimous': 'valiant',
    'cowardly': 'heroic',
    'fearful': 'intrepid',
    'faint-hearted': 'bold',
    'timid': 'venturesome',
    'unadventurous': 'adventurous',
    'risk-averse': 'risk-taking',
    'pitiful': 'admirable',
    'pitiable': 'laudable',
    'contemptible': 'praiseworthy',
    'despicable': 'commendable',
    'deplorable': 'noteworthy',
    'berated': 'applauded',
    'criticism': 'applause',
    'proud': 'disappointed',
    'condemn': 'acclaim',
    'maligne': 'celebrate',
    'disregarde': 'acknowledge',
    'ignore': 'recognize',
    'obscure': 'eminent',
    'unknown': 'renowned',
    'obscure': 'famous',
    'disreputable': 'illustrious',
    'disrespected': 'respected',
    'dishonored': 'honored',
    'disesteemed': 'esteemed',
    'reviled': 'adored',
    'vilified': 'revered',
    'condemned': 'venerated',
    'abhorred': 'glorified',
    'highly': 'lowly',
    'well-regarded': 'poorly regarded',
    'highly': 'poorly',
    'celebrate': 'protest',
    'for': 'against',
    'criticise': 'praise',
    'sad': 'happy',
    'happy': 'sad',
    'disappointed': 'proud',
    'big': 'small',
    'small': 'big',
    'loss':'gain',
    'gain':'loss',
    'not ':' ', 
}

# %%
def invert_sentence(sentence, positive_to_negative):
    words = sentence.split()
    inverted_sentence = []
    for word in words:
        # Check if any part of the word is in the positive_to_negative dictionary
        found = False
        for pos_word, neg_word in positive_to_negative.items():
            if pos_word in word.lower():
                inverted_sentence.append(word.lower().replace(pos_word, neg_word))
                found = True
                break
        if not found:
            inverted_sentence.append(word)
    return ' '.join(inverted_sentence)

# %%
# Function to create fake headlines
def create_fake_headline(headline):
    fake_headline = invert_sentence(headline, positive_to_negative)
    return fake_headline

# %%
pip install flair
# Out:
# Requirement already satisfied: flair in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.13.1)
# Requirement already satisfied: boto3>=1.20.27 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (1.34.93)
# Requirement already satisfied: bpemb>=0.3.2 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (0.3.5)
# Requirement already satisfied: conllu>=4.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (4.5.3)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (1.2.14)
# Requirement already satisfied: ftfy>=6.1.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (6.1.1)
# Requirement already satisfied: gdown>=4.4.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (5.1.0)
# Requirement already satisfied: gensim>=4.2.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (4.3.2)
# Requirement already satisfied: huggingface-hub>=0.10.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (0.22.2)
# Requirement already satisfied: janome>=0.4.2 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (0.5.0)
# Requirement already satisfied: langdetect>=1.0.9 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (1.0.9)
# Requirement already satisfied: lxml>=4.8.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (5.1.0)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (3.8.0)
# Requirement already satisfied: more-itertools>=8.13.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (10.2.0)
# Requirement already satisfied: mpld3>=0.3 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (0.5.10)
# Requirement already satisfied: pptree>=3.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (2.8.2)
# Requirement already satisfied: pytorch-revgrad>=0.2.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (0.2.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (2023.12.25)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (1.3.1)
# Requirement already satisfied: segtok>=1.5.11 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (1.5.11)
# Requirement already satisfied: sqlitedict>=2.0.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (2.1.0)
# Requirement already satisfied: tabulate>=0.8.10 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (0.9.0)
# Requirement already satisfied: torch!=1.8,>=1.5.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (2.2.2)
# Requirement already satisfied: tqdm>=4.63.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (4.66.1)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.3 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (0.4.0)
# Requirement already satisfied: transformers[sentencepiece]<5.0.0,>=4.18.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (4.40.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.0.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (1.26.15)
# Requirement already satisfied: wikipedia-api>=0.5.7 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (0.6.0)
# Requirement already satisfied: semver<4.0.0,>=3.0.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flair) (3.0.2)
# Requirement already satisfied: botocore<1.35.0,>=1.34.93 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from boto3>=1.20.27->flair) (1.34.93)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from boto3>=1.20.27->flair) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from boto3>=1.20.27->flair) (0.10.1)
# Requirement already satisfied: numpy in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bpemb>=0.3.2->flair) (1.26.4)
# Requirement already satisfied: requests in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bpemb>=0.3.2->flair) (2.31.0)
# Requirement already satisfied: sentencepiece in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bpemb>=0.3.2->flair) (0.2.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from deprecated>=1.2.13->flair) (1.14.1)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ftfy>=6.1.0->flair) (0.2.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gdown>=4.4.0->flair) (4.12.2)
# Requirement already satisfied: filelock in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gdown>=4.4.0->flair) (3.12.0)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim>=4.2.0->flair) (1.13.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim>=4.2.0->flair) (7.0.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.10.0->flair) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.10.0->flair) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.10.0->flair) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.10.0->flair) (4.8.0)
# Requirement already satisfied: six in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langdetect>=1.0.9->flair) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.3->flair) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.3->flair) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.3->flair) (4.36.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.3->flair) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.3->flair) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.3->flair) (3.0.9)
# Requirement already satisfied: jinja2 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from mpld3>=0.3->flair) (3.1.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=1.0.2->flair) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=1.0.2->flair) (3.1.0)
# Requirement already satisfied: sympy in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch!=1.8,>=1.5.0->flair) (1.11.1)
# Requirement already satisfied: networkx in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch!=1.8,>=1.5.0->flair) (3.1)
# Requirement already satisfied: colorama in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.63.0->flair) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (0.4.3)
# Requirement already satisfied: protobuf in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (4.23.3)
# Requirement already satisfied: accelerate>=0.21.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (0.29.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4->gdown>=4.4.0->flair) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->mpld3>=0.3->flair) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->bpemb>=0.3.2->flair) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->bpemb>=0.3.2->flair) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->bpemb>=0.3.2->flair) (2022.12.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->bpemb>=0.3.2->flair) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->torch!=1.8,>=1.5.0->flair) (1.3.0)
# Requirement already satisfied: psutil in c:\users\shubhi agarwal\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from accelerate>=0.21.0->transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (5.9.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: C:\Users\Shubhi Agarwal\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from flair.models import TextClassifier
from flair.data import Sentence

def get_sentiment(description):
    '''This function returns the sentiment of a statement.'''
    classifier = TextClassifier.load('en-sentiment')
    flair_sentence = Sentence(description)
    classifier.predict(flair_sentence)
    label = flair_sentence.labels[0].value
    return label

# %%
sentence = "I love this product! It's amazing."
sentiment= get_sentiment(sentence)
print("Sentiment:", sentiment)

# %%
# Output will be a modified sentence
orig_statement = 'People are protesting against the new law'
print("Orig:", orig_statement)
print(create_fake_headline(orig_statement))
# Out:
# Orig: People are protesting against the new law
# People are celebrateing for the new law

# %%
# Load the CSV file
csv_filename = 'extracted_data.csv'
df_ed = pd.read_csv(csv_filename)

# %%
descriptions = df_ed['desc']

# Analyze sentiment and add a new column 'label'
df_ed['label'] = descriptions.apply(lambda x: get_sentiment(x))

# Save the modified DataFrame back to the CSV file
df_ed.to_csv('extracted_data.csv', index=False)

# %%
df_ed.columns
# Out:
# Index(['article_id', 'url', 'image_url', 'headline', 'desc', 'label',
#        'modified_title'],
#       dtype='object')

# %%
def modify_title(row):
    '''This function applies the invert_sentence based on the label'''
    sentiment = row['label']
    title = row['headline']
    if sentiment in ['POSITIVE', 'NEUTRAL']:
        return invert_sentence(title, positive_to_negative)
    else:
        return invert_sentence(title, negative_to_positive)

# %%
df_ed['modified_title'] = df_ed.apply(modify_title, axis=1)
# Save the modified DataFrame back to the CSV file
df_ed.to_csv('extracted_data.csv', index=False)

# %%
# Apply the function to create fake headlines and store in 'Fake_headline' column
df_ed['Fake_headline'] = df_ed['headline'].apply(create_fake_headline)

# Save the modified DataFrame to a new CSV file
csv_filename = 'extracted_data.csv'
df_ed.to_csv(new_csv_filename, index=False)

print(f"Fake headlines created and saved to {csv_filename}")
# Out:
# Fake headlines created and saved to extracted_data.csv

# %%
# Read the two CSV files
extracted_data = pd.read_csv('extracted_data.csv')
news_article = pd.read_csv('News_Articles_Indian_Express.csv')
extracted_data.columns
# Out:
# Index(['article_id', 'url_x', 'image_url_x', 'headline_x', 'desc_x', 'label_x',
#        'modified_title', 'Fake_headline_x', 'Unnamed: 0', 'headline_y',
#        'desc_y', 'date', 'url_y', 'articles', 'article_type', 'article_length',
#        'label_y', 'image_url_y', 'headline', 'Fake_headline_y', 'desc', 'url'],
#       dtype='object')

# %%
news_article.columns
# Out:
# Index(['Unnamed: 0', 'article_id', 'headline', 'desc', 'date', 'url',
#        'articles', 'article_type', 'article_length'],
#       dtype='object')

# %%
# Merge the two DataFrames on the 'article_id' column, for common columns
common_columns = pd.merge(extracted_data, news_article, on='article_id', how='left')

# Select specific columns from each DataFrame
specific_columns_left = extracted_data[['article_id', 'label', 'image_url', 'headline', 'Fake_headline']]
specific_columns_right = news_article[['article_id', 'desc', 'date', 'url', 'articles', 'article_length']]

# Merge the specific columns from each DataFrame with the common columns DataFrame
merged_df = pd.merge(common_columns, specific_columns_left, on='article_id', how='left')
merged_df[['desc', 'date', 'url', 'articles', 'article_length']] = specific_columns_right[['desc', 'date', 'url', 'articles', 'article_length']]

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('extracted_data.csv', index=False)

# %%
extracted_data.drop(columns = ['headline_x', 'headline_y','desc_x','url_x', 'url_y','Unnamed: 0', 'image_url_x', 'label_x' , 'Fake_headline_x', 'Fake_headline_y'], inplace = True)

# %%
extracted_data.rename(columns = {'image_url_y':'image_url','label_y':'label', 'desc_y':'description' }, inplace = True)

# %%
extracted_data.columns
# Out:
# Index(['article_id', 'modified_title', 'description', 'date', 'articles',
#        'article_type', 'article_length', 'label', 'image_url', 'headline',
#        'desc', 'url'],
#       dtype='object')
